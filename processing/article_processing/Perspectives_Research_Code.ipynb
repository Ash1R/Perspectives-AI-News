# %%
# !pip3 install openai
# !pip install functions-framework
# !pip3 install POT
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.20.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Requirement already satisfied: functions-framework in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: flask<4.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from functions-framework) (2.2.5)
# Requirement already satisfied: click<9.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from functions-framework) (8.1.7)
# Requirement already satisfied: watchdog>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from functions-framework) (4.0.0)
# Requirement already satisfied: cloudevents<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from functions-framework) (1.10.1)
# Requirement already satisfied: gunicorn>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from functions-framework) (22.0.0)
# Requirement already satisfied: deprecation<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from cloudevents<2.0.0,>=1.2.0->functions-framework) (2.1.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask<4.0,>=1.0->functions-framework) (3.0.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask<4.0,>=1.0->functions-framework) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask<4.0,>=1.0->functions-framework) (2.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gunicorn>=19.2.0->functions-framework) (24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask<4.0,>=1.0->functions-framework) (2.1.5)
# Requirement already satisfied: POT in /usr/local/lib/python3.10/dist-packages (0.9.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from POT) (1.25.2)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/dist-packages (from POT) (1.11.4)

# %%
import gensim
print(gensim.__version__)
import gensim.downloader as api
print(api.info())
google_news = api.load("glove-wiki-gigaword-50")
# Out:
# 4.3.2
# {'corpora': {'semeval-2016-2017-task3-subtaskBC': {'num_records': -1, 'record_format': 'dict', 'file_size': 6344358, 'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/semeval-2016-2017-task3-subtaskB-eng/__init__.py', 'license': 'All files released for the task are free for general research use', 'fields': {'2016-train': ['...'], '2016-dev': ['...'], '2017-test': ['...'], '2016-test': ['...']}, 'description': 'SemEval 2016 / 2017 Task 3 Subtask B and C datasets contain train+development (317 original questions, 3,169 related questions, and 31,690 comments), and test datasets in English. The description of the tasks and the collected data is given in sections 3 and 4.1 of the task paper http://alt.qcri.org/semeval2016/task3/data/uploads/semeval2016-task3-report.pdf linked in section “Papers” of https://github.com/RaRe-Technologies/gensim-data/issues/18.', 'checksum': '701ea67acd82e75f95e1d8e62fb0ad29', 'file_name': 'semeval-2016-2017-task3-subtaskBC.gz', 'read_more': ['http://alt.qcri.org/semeval2017/task3/', 'http://alt.qcri.org/semeval2017/task3/data/uploads/semeval2017-task3.pdf', 'https://github.com/RaRe-Technologies/gensim-data/issues/18', 'https://github.com/Witiko/semeval-2016_2017-task3-subtaskB-english'], 'parts': 1}, 'semeval-2016-2017-task3-subtaskA-unannotated': {'num_records': 189941, 'record_format': 'dict', 'file_size': 234373151, 'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/semeval-2016-2017-task3-subtaskA-unannotated-eng/__init__.py', 'license': 'These datasets are free for general research use.', 'fields': {'THREAD_SEQUENCE': '', 'RelQuestion': {'RELQ_CATEGORY': 'question category, according to the Qatar Living taxonomy', 'RELQ_DATE': 'date of posting', 'RELQ_ID': 'question indentifier', 'RELQ_USERID': 'identifier of the user asking the question', 'RELQ_USERNAME': 'name of the user asking the question', 'RelQBody': 'body of question', 'RelQSubject': 'subject of question'}, 'RelComments': [{'RelCText': 'text of answer', 'RELC_USERID': 'identifier of the user posting the comment', 'RELC_ID': 'comment identifier', 'RELC_USERNAME': 'name of the user posting the comment', 'RELC_DATE': 'date of posting'}]}, 'description': 'SemEval 2016 / 2017 Task 3 Subtask A unannotated dataset contains 189,941 questions and 1,894,456 comments in English collected from the Community Question Answering (CQA) web forum of Qatar Living. These can be used as a corpus for language modelling.', 'checksum': '2de0e2f2c4f91c66ae4fcf58d50ba816', 'file_name': 'semeval-2016-2017-task3-subtaskA-unannotated.gz', 'read_more': ['http://alt.qcri.org/semeval2016/task3/', 'http://alt.qcri.org/semeval2016/task3/data/uploads/semeval2016-task3-report.pdf', 'https://github.com/RaRe-Technologies/gensim-data/issues/18', 'https://github.com/Witiko/semeval-2016_2017-task3-subtaskA-unannotated-english'], 'parts': 1}, 'patent-2017': {'num_records': 353197, 'record_format': 'dict', 'file_size': 3087262469, 'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/patent-2017/__init__.py', 'license': 'not found', 'description': "Patent Grant Full Text. Contains the full text including tables, sequence data and 'in-line' mathematical expressions of each patent grant issued in 2017.", 'checksum-0': '818501f0b9af62d3b88294d86d509f8f', 'checksum-1': '66c05635c1d3c7a19b4a335829d09ffa', 'file_name': 'patent-2017.gz', 'read_more': ['http://patents.reedtech.com/pgrbft.php'], 'parts': 2}, 'quora-duplicate-questions': {'num_records': 404290, 'record_format': 'dict', 'file_size': 21684784, 'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/quora-duplicate-questions/__init__.py', 'license': 'probably https://www.quora.com/about/tos', 'fields': {'question1': 'the full text of each question', 'question2': 'the full text of each question', 'qid1': 'unique ids of each question', 'qid2': 'unique ids of each question', 'id': 'the id of a training set que ...

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db
from firebase_admin import firestore

from google.colab import drive
drive.mount('/content/drive')
file_path = "/content/drive/My Drive/perspectives-27600-firebase-adminsdk-7qya7-23bbf7ed92.json"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cred = credentials.Certificate(file_path)
app = firebase_admin.initialize_app(cred)

# %%
doc1 = ['totalitarian',
'as',
'long',
'repression',
'kinda',
'indeed',
'hide',
'bad',
'get',
'fundamentalists',
'mistake',
'leaders',
'darned',
'entertaining',
'word',
'disinformation',
'happened',
'spirit',
'muslims',
'arrogant',
'crimes',
'ironic',
'lack',
'potentially',
'taken',
'right',
'actions',
'horror',
'frustrating',
'nightmare',
'ignore',
'sense',
'war',
'punishment',
'straightforward',
'anger',
'intense',
'traitor',
'traitors',
'remember',
'denounce',
'humanity',
'escalation',
'sudden',
'blatantly',
'islamic',
'vengeance',
'genuinely',
'fury',
'call',
'censorship',
'my',
'curb',
'politicians',
'basically',
'sadly',
'lousy',
'betrayal',
'hypocrisy',
'unpleasant',
'fraud',
'sentiments',
'fear',
'attention',
'taking',
'deeply',
'publicly',
'the',
'not',
'driven',
'worrying',
'ordinary',
'sorts',
'shame',
'among',
'describing',
'memories',
'moderate',
'aggression',
'completely',
'zionist',
'wave',
'social',
'knowing',
'nevertheless',
'truly',
'today',
'frankly',
'does',
'go',
'sight',
'remarks',
'consider',
'bit',
'growing',
'horrific',
'could',
'racist',
'notion',
'manipulation',
'feelings',
'away',
'although',
'fundamentalist',
'odious',
'openly',
'preposterous',
'nationalistic',
'than',
'turn',
'?',
'whites',
'certainly',
'wonder',
'getting',
'widespread',
'presence',
'feeling',
'acts',
'cruel',
'tendency',
'religious',
'unwarranted',
'insulting',
'talk',
'mad',
'threats',
'moral',
'like',
'increasing',
'voters',
'plainly',
'pathetic',
'barbaric',
'tell',
'exceedingly',
'referring',
'jealousy',
'fault',
'your',
'repeat',
'punish',
'belligerent',
'escape',
'nasty',
'take',
'unjustified',
'perceived',
'might',
'irresponsible',
'apparent',
'plain',
'inconvenient',
'mentality',
'aggressive',
'disdain',
'rule',
'calls',
'protests',
disgusting inhuman even despite repeated poor foolish awful seemingly unsettling denouncing towards happens wars put statements discourage clearly very hardly oppression behavior sort pretext however keep terrorism without harsh hate undeniably problem unfortunately been cases believe pity weird turning equally those nation result terror wow trying unleashed stupidity mistaken here immoral chaos demands seeming distressing reality repressive strange sad should cynical negative nazi anybody relentless ! provoked criticisms complaining their toward unbelievably tragic publicity rude thoughts rhetoric more confusing tough violent orchestrated nature rage propaganda antisemitic disturbing boring critics threat wherever situation easy panic unlawful drug evident largely economic reactionary extremism accusations somebody revolt awesome predictable excesses misunderstanding only possible wake move retaliation ideological easier genocidal stuff thing angry drugs attitudes lest cause dealing outrageous risk everything afraid excuse fun shocked unfortunate whose danger carnage harassment scared years emotional millions do outrage abuses worse naive down inaction rather gone instead hostile despicable vicious now you pressure bitterness yes illusion fascinating costly unseemly ignorance ignorant for unjust once corrupt greed posturing terrorist happiness views provoking criticize though mocking murder smuggling fraudulent change regard influence stranger up still continued decades itself vandalism terribly totally values some protect painful nationalist opposition much forget dumb particularly enemy actually contrary cursed counterproductive wacky ease same again massive scary criticized words ludicrous he hysterical nothing nationalism supposed fantastic because downright or heinous ca dare always strongly resistance surely mean laughable awfully something populist incite realize recent involving condemned happen we interesting opponents regime say mostly see drunk done odd overwhelming particular hilarious obsessed disgusted instances so indifference vulgar them sorry pretty crime obvious cannot shocking seems conservatives these this bloody extremists funny people did perception hopeless dislike how misuse criticism distasteful animosity other confrontational kind there activities making what sometimes divisive dishonest whatever past life heaven incessant scandalous mainly handling radical wrath well bigotry cheap yeah make clever de ...

# %%
pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.2/142.2 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.5/664.5 kB 16.8 MB/s eta 0:00:00

# %%
import google.generativeai as genai
GOOGLE_API_KEY = "AIzaSyBr2Sed8To1eVK79LPh9hTwGh6UDXnrYJY"

genai.configure(api_key="AIzaSyBr2Sed8To1eVK79LPh9hTwGh6UDXnrYJY")

# Set up the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 0,
  "max_output_tokens": 8192,
}

safety_settings = [
    {
            "category": "HARM_CATEGORY_DANGEROUS",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
            "threshold": "BLOCK_NONE",
        },

]

model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                            )



#convo.send_message("YOUR_USER_INPUT")
#print(convo.last.text)

# %%
#console ver
apik = "de0e511c385d48fb888a0c1f65ffecc2"
#"de0e511c385d48fb888a0c1f65ffecc2"
#"bc3d29786d494de3bafd87dff24fc7e2"
#f2d26ba2ad30471ba50fb04f39764018
import requests
import os
import traceback

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from tqdm import tqdm
import re
import bs4

import firebase_admin
from firebase_admin import credentials
from firebase_admin import db
from firebase_admin import firestore

import gensim
import gensim.downloader as api
from bs4 import BeautifulSoup
from bs4.element import Comment
import functions_framework
import openai
import ot
import time

from datetime import date

@functions_framework.http
def hello_http(request):
  """HTTP Cloud Function.
  Args:
  request (flask.Request): The request object.
  <https://flask.palletsprojects.com/en/1.1.x/api/#incoming-request-data>
  Returns:
  The response text, or any set of values that can be turned into a
  Response object using `make_response`
  <https://flask.palletsprojects.com/en/1.1.x/api/#flask.make_response>.
  """
  request_json = request


  db = firestore.client()
  country = request_json["country"]
  date= request_json["date"]
  yesterday = request_json["yesterday"]
  categories = ["general", "business", "technology", "science", "sports", "entertainment", "health"]
  id = 1
  for cat in categories:
    print("https://us-central1-perspectives-27600.cloudfunctions.net/top-headlines1?country=us&from="+yesterday+"&to=" + date +"&category=" + cat + "&type=top-headlines&replacer=placeholder&apik=" + apik)
    data = requests.get("https://us-central1-perspectives-27600.cloudfunctions.net/top-headlines1?country=us&from="+yesterday+"&to=" + date +"&category=" + cat + "&type=top-headlines&replacer=placeholder&apik=" + apik).json()
    #print("https://newsapi.org/v2/top-headlines?country=" + country+ "&from=" + date+ "&to=" + date + "&category=" + cat+ "&sortBy=popularity&apiKey=f2d26ba2ad30471ba50fb04f39764018")
    comb_text = {}
    print(data)
    for i in data["articles"][:4]:
      in_text = i["title"]
      if i["description"]:
        in_text += i["description"]
      if i["content"]:
        in_text += i["content"]
      comb_text[in_text] = i
   # headers = {"Authorization": f"Bearer {openkey}"}
    keywords = {}
    print(comb_text)
    for i in comb_text:
      storieslst =[]
      if i:
        try:
          print("before sending the excerpt to openai")
          convo = model.start_chat(history=[])
          convo.send_message("Read this excerpt and answer the question after the & signs:\n" +i[:100] + "\n&&&&&&&&&&\n What is the topic of this article, defined in 2 words or less, that I can use to find other articles on this topic, in the excerpt? Answer with JUST the 2 or less words.")
          print(convo.last.text)

         #data = {"model": "gpt-3.5-turbo", "messages": [{"role": "user", "content": "Read this excerpt and answer the question after the & signs:\n" + i[:500] + "\n&&&&&&&&&&\n What is the topic of this article, defined in 2 words or less, that I can use to find other articles on this topic, in the excerpt? Answer with JUST the 2 or less words."}], "temperature": 0.7}
          #response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=data).json()
          print("response from openai")
          #print(response)
          keywords[convo.last.text] = comb_text[i]
          time.sleep(3)
        except Exception:
          traceback.print_exc()
          print("keyword failed")
    #    google_news = api.load("glove-wiki-gigaword-100")

    google_news = api.load("glove-wiki-gigaword-50")
    for i in keywords:
      print(keywords)
      print(len(keywords))
      print("flag")
      biases = {}

      print(i)
      replacer = i
      topicart = requests.get("https://us-central1-perspectives-27600.cloudfunctions.net/top-headlines1?country=us&from=" + yesterday + "&to=" + date+ "&category=" + cat + "&type=everything&replacer=" + replacer+ "&apik=" + apik)
      topicson = topicart.json()
      for art in topicson["articles"][:4]:
        biases[str(google_news.wmdistance(extract(art["url"]), doc1))] = art
      biases[str(google_news.wmdistance(extract(keywords[i]["url"]), doc1))] = keywords[i]
      biases["date"] = str(date)
      biases["cat"] = cat
      biases["keyword"] = i
      biases["country"] = country
      doc_ref = db.collection("topics").document(str(id) + "-" + str(yesterday) + "-" + cat + "-" + i)
      print(biases)
      print("IT SHOULD SET HERE")
      doc_ref.set(biases)
      id+=1
  #print(storieslst)
  return storieslst


def extract(url):
  # Specify the URL of the news webpage


  # Send a GET request to the webpage
  print(url)
  try:
    response = requests.get(url)
  except:
    print("whoops")
    return "inf"


  # Create a BeautifulSoup object to parse the HTML content
  soup = BeautifulSoup(response.content, "html.parser")


  # Function to check if an element is a tag containing visible text
  def tag_visible(element):
    if element.parent.name in ["style", "script", "head", "title", "meta", "[document]"]:
      return False
    if isinstance(element, Comment):
      return False
    return True

  # Find all visible text elements on the webpage
  text_elements = soup.findAll(text=True)
  visible_texts = filter(tag_visible, text_elements)


  # Filter the visible text elements to get those longer than 100 characters
  long_texts = [re.sub('\s+',' ',text.strip()) for text in visible_texts if (len(re.sub('\s+',' ',text.strip())) > 100 and "newsletter" not in (text.strip().lower()) and "notification" not in text.strip().lower())]
  # Print the long texts
  return preprocessing((" ".join(long_texts)).split(" "))

def preprocessing(titles_array):
  final = []
  for title in tqdm(titles_array):
    processed = re.sub('[^a-zA-Z ]', '', title)

    words = processed.lower().split()
    stop_words = set(stopwords.words('english'))

    # keep words that have length of more than 1 (e.g. gb, bb), remove those with length 1.
    final.append(' '.join([word for word in words if (len(word) > 1 and word not in stop_words)]))
  return [i for i in final if i!= ""]


# Returns the current local date
from datetime import timedelta

today=date.today()


hello_http({"country": "us", "date": str(today), "yesterday": (str(today  - timedelta(days=1)))})
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# https://us-central1-perspectives-27600.cloudfunctions.net/top-headlines1?country=us&from=2024-04-16&to=2024-04-17&category=general&type=top-headlines&replacer=placeholder&apik=de0e511c385d48fb888a0c1f65ffecc2
# {'status': 'ok', 'totalResults': 38, 'articles': [{'source': {'id': None, 'name': 'The Athletic'}, 'author': 'Ben Pickman', 'title': 'Fever select Caitlin Clark with No. 1 pick in WNBA Draft - The Athletic', 'description': 'In elementary school, she wrote down one of her future goals: to make the WNBA. On Monday night, that aspiration became a reality.', 'url': 'https://theathletic.com/5417306/2024/04/15/caitlin-clark-wnba-draft-indiana-fever-first-pick-basketball/', 'urlToImage': 'https://cdn.theathletic.com/app/uploads/2024/04/15194545/GettyImages-2148763333-1-scaled.jpg', 'publishedAt': '2024-04-16T06:00:13Z', 'content': 'BROOKLYN, N.Y. Eight days after completing one of the greatest collegiate basketball careers ever recorded, Caitlin Clark was selected with the No. 1 pick in Mondays WNBA Draft by the Indiana Fever.\r… [+3995 chars]'}, {'source': {'id': 'axios', 'name': 'Axios'}, 'author': 'Axios', 'title': 'FBI conducts "law enforcement activity" aboard cargo ship that struck Baltimore bridge - Axios', 'description': None, 'url': 'https://www.axios.com/2024/04/15/fbi-cargo-ship-baltimore-bridge-collapse', 'urlToImage': None, 'publishedAt': '2024-04-16T05:19:58Z', 'content': None}, {'source': {'id': None, 'name': 'BBC News'}, 'author': None, 'title': 'China economy grows faster than expected in first quarter - BBC.com', 'description': "Official figures also highlighted the challenges faced by the country's crisis-hit property sector.", 'url': 'https://www.bbc.com/news/business-68823396', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1577/production/_133159450_gettyimages-2147041765.jpg', 'publishedAt': '2024-04-16T04:46:36Z', 'content': None}, {'source': {'id': None, 'name': 'BBC News'}, 'author': None, 'title': "Sydney church stabbing declared a 'terrorist' attack - BBC.com", 'description': 'A 16-year-old boy is under arrest after a bishop and several churchgoers were injured on Monday.', 'url': 'https://www.bbc.com/news/world-australia-68823240', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/379B/production/_133153241_520efdf7c31595b66ec16a0b5b7ca4d242d8ad560_0_5495_28831000x525.jpg', 'publishedAt': '2024-04-16T04:33:49Z', 'content': None}, {'source': {'id': 'cnn', 'name': 'CNN'}, 'author': 'Krystal Hur, David Goldman', 'title': 'Trump stock tanks after announcing massive share sale - CNN', 'description': 'Trump Media & Technology Group’s stock is tumbling again after the company announced a massive new influx of shares.', 'url': 'https://www.cnn.com/2024/04/15/investing/trump-stock-new-shares/index.html', 'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2148449799-20240415125851005.jpg?c=16x9&q=w_800,c_fill', 'publishedAt': '2024-04-16T02:13:00Z', 'content': 'Trump Media &amp; Technology Groups stock is tumbling again after the company announced a potentially massive new influx of shares. The struggling company is rapidly losing money, and a new stock off… [+4468 chars]'}, {'source': {'id': None, 'name': 'SFGate'}, 'author': 'SFGATE', 'title': "'Idiots': 2 men sought for destroying ancient Nev. rock formation - SFGATE", 'description': None, 'url': 'https://www.sfgate.com/travel/article/men-sought-destroying-nevada-rock-formation-19403847.php', 'urlToImage': None, 'publishedAt': '2024-04-16T01:52:30Z', 'content': None}, {'source': {'id': None, 'name': 'New York Post'}, 'author': 'Associated Press', 'title': 'NASA confirms mystery object that crashed through roof of Florida home came from space station - New York Post ', 'description': 'The cylindrical object that tore through the home in Naples on March 8 was subsequently taken to the Kennedy Space Center in Cape Canaveral for analysis.', 'url': 'https://nypost.com/2024/04/15/us-news/nasa-confirms-mystery-object-that-crashed-through-roof-of-florida-home-came-from-space-station/', 'urlToImage': 'https://nypost.com/wp-content/uploads/sites/2/2024/04/newspress-collage-26emqp4ci-1713231182127.jpg?quality=75&strip=a ...
# {'Fever select Caitlin Clark with No. 1 pick in WNBA Draft - The AthleticIn elementary school, she wrote down one of her future goals: to make the WNBA. On Monday night, that aspiration became a reality.BROOKLYN, N.Y. Eight days after completing one of the greatest collegiate basketball careers ever recorded, Caitlin Clark was selected with the No. 1 pick in Mondays WNBA Draft by the Indiana Fever.\r… [+3995 chars]': {'source': {'id': None, 'name': 'The Athletic'}, 'author': 'Ben Pickman', 'title': 'Fever select Caitlin Clark with No. 1 pick in WNBA Draft - The Athletic', 'description': 'In elementary school, she wrote down one of her future goals: to make the WNBA. On Monday night, that aspiration became a reality.', 'url': 'https://theathletic.com/5417306/2024/04/15/caitlin-clark-wnba-draft-indiana-fever-first-pick-basketball/', 'urlToImage': 'https://cdn.theathletic.com/app/uploads/2024/04/15194545/GettyImages-2148763333-1-scaled.jpg', 'publishedAt': '2024-04-16T06:00:13Z', 'content': 'BROOKLYN, N.Y. Eight days after completing one of the greatest collegiate basketball careers ever recorded, Caitlin Clark was selected with the No. 1 pick in Mondays WNBA Draft by the Indiana Fever.\r… [+3995 chars]'}, 'FBI conducts "law enforcement activity" aboard cargo ship that struck Baltimore bridge - Axios': {'source': {'id': 'axios', 'name': 'Axios'}, 'author': 'Axios', 'title': 'FBI conducts "law enforcement activity" aboard cargo ship that struck Baltimore bridge - Axios', 'description': None, 'url': 'https://www.axios.com/2024/04/15/fbi-cargo-ship-baltimore-bridge-collapse', 'urlToImage': None, 'publishedAt': '2024-04-16T05:19:58Z', 'content': None}, "China economy grows faster than expected in first quarter - BBC.comOfficial figures also highlighted the challenges faced by the country's crisis-hit property sector.": {'source': {'id': None, 'name': 'BBC News'}, 'author': None, 'title': 'China economy grows faster than expected in first quarter - BBC.com', 'description': "Official figures also highlighted the challenges faced by the country's crisis-hit property sector.", 'url': 'https://www.bbc.com/news/business-68823396', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1577/production/_133159450_gettyimages-2147041765.jpg', 'publishedAt': '2024-04-16T04:46:36Z', 'content': None}, "Sydney church stabbing declared a 'terrorist' attack - BBC.comA 16-year-old boy is under arrest after a bishop and several churchgoers were injured on Monday.": {'source': {'id': None, 'name': 'BBC News'}, 'author': None, 'title': "Sydney church stabbing declared a 'terrorist' attack - BBC.com", 'description': 'A 16-year-old boy is under arrest after a bishop and several churchgoers were injured on Monday.', 'url': 'https://www.bbc.com/news/world-australia-68823240', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/379B/production/_133153241_520efdf7c31595b66ec16a0b5b7ca4d242d8ad560_0_5495_28831000x525.jpg', 'publishedAt': '2024-04-16T04:33:49Z', 'content': None}}
# before sending the excerpt to openai
# WNBA Draft
#
# response from openai
# before sending the excerpt to openai
# FBI investigation
#
# response from openai
# before sending the excerpt to openai
# China economy
#
# response from openai
# before sending the excerpt to openai
# Traceback (most recent call last):
#   File "<ipython-input-30-d8d27d682048>", line 75, in hello_http
#     convo.send_message("Read this excerpt and answer the question after the & signs:\n" +i[:100] + "\n&&&&&&&&&&\n What is the topic of this article, defined in 2 words or less, that I can use to find other articles on this topic, in the excerpt? Answer with JUST the 2 or less words.")
#   File "/usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py", line 483, in send_message
#     self._check_response(response=response, stream=stream)
#   File "/usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py", line 510, in _check_response
#     raise generation_types.StopCandidateException(response.candidates[0])
# google.generativeai.types.generation_types.StopCandidateException: finish_reason: SAFETY
# index: 0
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: MEDIUM
# }
# keyword failed

# %%
doc1=['jihadiste',
'gens',
'paternalisme',
'soi-disants',
'dénégations',
'acharnent',
'ressentiment',
'dictatoriale',
'tout',
'sexisme',
'condamnons',
'allégrement',
'stupide',
'rappelant',
'parler',
'perpétrer',
'choqué',
'machiste',
'attiser',
'racisme',
'vexations',
'légitimée',
'électoraliste',
'décrété',
'puisqu',
'évidemment',
'enrôlement',
'quand',
'crapuleux',
'forcenés',
'résigné',
'insultantes',
'décomplexée',
'chiites',
'indubitablement',
'agissements',
'xénophobie',
'réfugiées',
'dans',
'dénigrant',
'jamais',
'empêche',
'atterré',
'intolérables',
'conflit',
'denoncer',
'moquerie',
'ne',
'voudraient',
'instrumentalise',
'populiste',
'extrêmistes',
'déchaînement',
'discréditent',
'extrême',
'moralisatrice',
'croit',
'conséquence',
'punitives',
'justifie',
'incite',
'fachos',
'fermement',
'djihadistes',
'arrivistes',
'malheureusement',
'bafouent',
'suppôt',
'ni',
'peser',
'réacs',
'humiliantes',
'injustifiée',
'prétendent',
'surenchère',
'veulerie',
'obscurantismes',
'complaisent',
'relève',
'vain',
'intolérable',
'irak',
'représailles',
'coercition',
'prétexte',
'sorte',
'aveuglement',
'affreusement',
'inquiéter',
'accusée',
'ridicule',
'illégitimes',
'ethnisme',
'dénoncé',
'quant',
'certes',
'acabit',
'quasi',
'terriblement',
'imbécillité',
'bafouées',
'ouvertement',
'musulman',
'dénonciations',
'honni',
'ostracisme',
'médiatique',
'attardé',
'décrédibiliser',
'lamentables',
'accusateurs',
'militaire',
'vergogne',
'fondamentalismes',
'xénophobes',
'extrème',
'révolté',
'revendiquée',
'nation',
'haine',
'explique',
'celui',
'piège',
'ressasser',
'bafouant',
'perpétré',
'justifiée',
'proférées',
'anticolonialisme',
'assassinats',
'jusque',
'prétendu',
'contenter',
'pervertie',
'hostiles',
'clandestine',
'minable',
'tiers-mondistes',
'inadmissible',
'censurer',
'mal',
'désespérée',
'désespéré',
'sécuritaires',
'révoltante',
'vilipender',
'encore',
'prétextes',
'incompréhensible',
'gangrènent',
'crime',
'méprise',
'identitaire',
'pornographie',
'davantage',
'condamnable',
'traîtres',
'éclaté',
'fascisante',
'totalitaire',
'militer',
'euphémisme',
'tentent',
'discrédit',
'racismes',
'caricaturer',
'victimisation',
'agression',
'contrecoups',
'plaider']

# %%
from gensim.test.utils import datapath
from gensim.models import KeyedVectors

wv_from_bin = KeyedVectors.load_word2vec_format(datapath("/content/drive/MyDrive/cbow/cbowfr.bin"), binary=True, unicode_errors='ignore')

# %%
#console ver
apik = "de0e511c385d48fb888a0c1f65ffecc2"
# "bc3d29786d494de3bafd87dff24fc7e2"
#"de0e511c385d48fb888a0c1f65ffecc2"
#"bc3d29786d494de3bafd87dff24fc7e2"
import requests
import os

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from tqdm import tqdm
import re
import bs4

import firebase_admin
from firebase_admin import credentials
from firebase_admin import db
from firebase_admin import firestore

import gensim
import gensim.downloader as api
from bs4 import BeautifulSoup
from bs4.element import Comment
import functions_framework
import openai
import ot

from datetime import date

@functions_framework.http
def hello_http(request):
  """HTTP Cloud Function.
  Args:
  request (flask.Request): The request object.
  <https://flask.palletsprojects.com/en/1.1.x/api/#incoming-request-data>
  Returns:
  The response text, or any set of values that can be turned into a
  Response object using `make_response`
  <https://flask.palletsprojects.com/en/1.1.x/api/#flask.make_response>.
  """
  request_json = request


  db = firestore.client()
  country = request_json["country"]
  date= request_json["date"]
  yesterday = request_json["yesterday"]
  categories = ["general", "business", "technology", "science", "sports", "entertainment", "health"]
  id = 1
  for cat in categories:
    print("https://us-central1-perspectives-27600.cloudfunctions.net/top-headlines1?country=fr&from="+yesterday+"&to=" + date +"&category=" + cat + "&type=top-headlines&replacer=placeholder&apik=" + apik)
    data = requests.get("https://us-central1-perspectives-27600.cloudfunctions.net/top-headlines1?country=" + country+ "&from="+yesterday+"&to=" + date +"&category=" + cat + "&type=top-headlines&replacer=placeholder&apik=" + apik).json()
    #print("https://newsapi.org/v2/top-headlines?country=" + country+ "&from=" + date+ "&to=" + date + "&category=" + cat+ "&sortBy=popularity&apiKey=f2d26ba2ad30471ba50fb04f39764018")
    comb_text = {}
    print(data)
    for i in data["articles"][:4]:
      in_text = i["title"]
      if i["description"]:
        in_text += i["description"]
      if i["content"]:
        in_text += i["content"]
      comb_text[in_text] = i
    openkey = "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"
    headers = {"Authorization": f"Bearer {openkey}"}
    keywords = {}
    print(comb_text)
    for i in comb_text:
      storieslst =[]
      if i:
        data = {"model": "gpt-3.5-turbo", "messages": [{"role": "user", "content": "Read this excerpt and answer the question after the & signs:\n" + i + "\n&&&&&&&&&&\n What is the topic of this article, defined in 2 words or less, that I can use to find other articles on this topic, in the excerpt? Answer with JUST the 2 or less words."}], "temperature": 0.7}
        response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=data).json()
        try:
          print()
          keywords[response["choices"][0]["message"]["content"]] = comb_text[i]
        except:
          print("keyword failed")
    #    google_news = api.load("glove-wiki-gigaword-100")

    google_news = api.load("glove-wiki-gigaword-50")
    for i in keywords:
      print(keywords)
      print(len(keywords))
      print("flag")
      biases = {}

      print(i)
      replacer = i
      topicart = requests.get("https://us-central1-perspectives-27600.cloudfunctions.net/top-headlines1?country=us&from=" + yesterday + "&to=" + date+ "&category=" + cat + "&type=everything&replacer=" + replacer+ "&apik=" + apik)
      topicson = topicart.json()
      for art in topicson["articles"][:4]:
        biases[str(wv_from_bin.wmdistance(extract(art["url"]), doc1))] = art
      biases[str(wv_from_bin.wmdistance(extract(keywords[i]["url"]), doc1))] = keywords[i]
      biases["date"] = str(date)
      biases["cat"] = cat
      biases["keyword"] = i
      biases["country"] = country
      doc_ref = db.collection("topics").document(str(id) + "-" + str(yesterday) + "-" + cat + "-" + i+ "-" + country)
      print(biases)
      doc_ref.set(biases)
      id+=1
  #print(storieslst)
  return storieslst


def extract(url):
  # Specify the URL of the news webpage


  # Send a GET request to the webpage
  print(url)
  try:
    response = requests.get(url)
  except:
    print("whoops")
    return "inf"


  # Create a BeautifulSoup object to parse the HTML content
  soup = BeautifulSoup(response.content, "html.parser")


  # Function to check if an element is a tag containing visible text
  def tag_visible(element):
    if element.parent.name in ["style", "script", "head", "title", "meta", "[document]"]:
      return False
    if isinstance(element, Comment):
      return False
    return True

  # Find all visible text elements on the webpage
  text_elements = soup.findAll(text=True)
  visible_texts = filter(tag_visible, text_elements)


  # Filter the visible text elements to get those longer than 100 characters
  long_texts = [re.sub('\s+',' ',text.strip()) for text in visible_texts if (len(re.sub('\s+',' ',text.strip())) > 100 and "newsletter" not in (text.strip().lower()) and "notification" not in text.strip().lower())]
  # Print the long texts
  return preprocessing((" ".join(long_texts)).split(" "))

def preprocessing(titles_array):
  final = []
  for title in tqdm(titles_array):
    processed = re.sub('[^a-zA-Z ]', '', title)

    words = processed.lower().split()
    stop_words = set(stopwords.words('french'))

    # keep words that have length of more than 1 (e.g. gb, bb), remove those with length 1.
    final.append(' '.join([word for word in words if (len(word) > 1 and word not in stop_words)]))
  return [i for i in final if i!= ""]


# Returns the current local date
from datetime import timedelta

today=date.today()


hello_http({"country": "fr", "date": str(today), "yesterday": str(today - timedelta(days=1))})
